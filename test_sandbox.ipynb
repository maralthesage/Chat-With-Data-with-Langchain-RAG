# %%
import pandas as pd

# %%
df = pd.read_csv('/Volumes/MARAL/rechnung/rechnung_gesamt_combined.csv',encoding='utf-8',sep=';',parse_dates=['DATUM'])

# %%
df.columns

# %%
df[(df['DATUM'].dt.strftime('%Y-%m') == '2026-03')]['Netto_Umsatz'].sum()

# %%
df[(df['DATUM'].dt.year == 2024)&(df['DATUM'].dt.month == 9)]['AUFTRAG_NR'].count()
