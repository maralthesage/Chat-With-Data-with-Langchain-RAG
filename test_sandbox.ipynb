# %%
import pandas as pd

# %%
df = pd.read_csv('/Volumes/MARAL/rechnung/rechnung_gesamt_combined.csv',encoding='cp850',sep=';',parse_dates=['DATUM'])
# Out:
# /var/folders/5j/sk834jzs3cg8kh3yp7743_ym0000gp/T/ipykernel_35855/2363304076.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Volumes/MARAL/rechnung/rechnung_gesamt_combined.csv',encoding='cp850',sep=';',parse_dates=['DATUM'])

# %%
df.columns
# Out:
# Index(['NUMMER', 'AUFTRAG_NR', 'RECHNUNG', 'Land', 'SOURCE', 'DATUM',
#        'Herkunft', 'Brutto_Umsatz', 'Netto_Umsatz', 'Produkt', 'MENGE',
#        'Retouren', 'WG_NAME'],
#       dtype='object')

# %%
df[(df['DATUM'].dt.year == 2024)&(df['DATUM'].dt.month == 9)]['AUFTRAG_NR'].count()
# Out:
# np.int64(80416)
